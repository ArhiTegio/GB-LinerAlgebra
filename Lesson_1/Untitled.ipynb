# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
        x = np.arange(-2, 2, 0.01)
        y1 = np.exp(x)
        y2 = [1 for e in range(len(x))]
        y3 = x + 1
        y4 = x - np.exp(x)
        y5 = y1 + y4 + y2
        plt.plot(x, y1, 'k--', linewidth=3)
        plt.plot(x, y2, 'm-.')
        plt.plot(x, y3, color='#87a3cc', linestyle='--')
        plt.plot(x, y4, color='#cccccc', linestyle='solid')
        plt.plot(x, y5, color='#454545', linestyle='solid')
        plt.show()

# %%
        x = np.arange(-2, 2, 0.01)
        y1 = [2 for e in range(len(x))]
        y2 = x
        y3 = x**2
        y4 = (x + 1) ** 2
        y5 = y4 - y3 - y2 - np.array(y1) / 2 
        plt.plot(x, y1, 'k--', linewidth=3)
        plt.plot(x, y2, 'm-.')
        plt.plot(x, y3, color='#87a3cc', linestyle='--')
        plt.plot(x, y4, color='#cccccc', linestyle='solid')
        plt.plot(x, y5, color='#454545', linestyle='solid')
        plt.show()
